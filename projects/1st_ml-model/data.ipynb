# %%
import zipfile

with zipfile.ZipFile('./data/student-productivity-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('./data')

print("done")
# Out:
# done

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

print(os.listdir('./data'))
# Out:
# ['student-productivity-dataset.zip', 'Student_Productivity_Dataset.csv']

# %%
df = pd.read_csv('./data/Student_Productivity_Dataset.csv')

df.head()
# Out:
#    Student_ID   Age  Gender  Study_Hours_Per_Day  Sleep_Hours_Per_Night  \
# 0           1  19.0    Male                  2.6                    5.9
# 1           2  25.0    Male                  5.4                    6.4
# 2           3  22.0    Male                  6.8                    5.5
# 3           4  21.0  Female                  1.7                    8.0
# 4           5  17.0    Male                  7.6                    6.2
#
#    Screen_Time_Hours  Social_Media_Hours  Attendance_Percentage  \
# 0                7.4                 2.8                   86.3
# 1                6.4                 4.1                   93.3
# 2                7.4                 4.3                   66.3
# 3                6.2                 2.4                   62.8
# 4                4.3                 3.7                   87.9
#
#    Assignments_Completed  Class_Participation_Score  \
# 0                   75.1                        3.8
# ...

# %%
df.shape
# Out:
# (10000, 20)

# %% [markdown]
# PREPROCESSING

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Student_ID                        10000 non-null  int64
#  1   Age                               9845 non-null   float64
#  2   Gender                            9881 non-null   str
#  3   Study_Hours_Per_Day               9835 non-null   float64
#  4   Sleep_Hours_Per_Night             9894 non-null   float64
#  5   Screen_Time_Hours                 9868 non-null   float64
#  6   Social_Media_Hours                9920 non-null   float64
#  7   Attendance_Percentage             9878 non-null   float64
#  8   Assignments_Completed             9882 non-null   float64
#  9   Class_Participation_Score         9815 non-null   float64
#  10  Physical_Activity_Hours_Per_Week  9863 non-null   float64
# ...

# %%
df.describe()
df.isnull().sum()
# Out:
# Student_ID                            0
# Age                                   0
# Gender                              119
# Study_Hours_Per_Day                   0
# Sleep_Hours_Per_Night                 0
# Screen_Time_Hours                     0
# Social_Media_Hours                    0
# Attendance_Percentage                 0
# Assignments_Completed                 0
# Class_Participation_Score             0
# Physical_Activity_Hours_Per_Week      0
# Stress_Level                          0
# Motivation_Level                      0
# Internet_Quality                    149
# Part_Time_Job                       126
# Extracurricular_Involvement           0
# AI_Tool_Usage_Hours_Per_Week          0
# Previous_Semester_GPA                 0
# Productivity_Score                    0
# Performance_Category                  0
# dtype: int64

# %%
df.fillna(df.median(numeric_only=True), inplace=True) # fill missing values with median for numeric columns
df.isnull().sum() # check for missing values again
df = df.drop('Student_ID', axis=1)

# %% [markdown]
# EDA

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Study_Hours_Per_Day',
    y='Productivity_Score'
)

plt.title("Study Hours vs Productivity Score")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Sleep_Hours_Per_Night',
    y='Productivity_Score'
)

plt.title("Sleep Hours vs Productivity Score")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Screen_Time_Hours',
    y='Productivity_Score'
)

plt.title("Screen Time vs Productivity Score")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Social_Media_Hours',
    y='Productivity_Score'
)

plt.title("Social Media Hours vs Productivity Score")
plt.show()

# %%
lifestyle = df[
[
'Study_Hours_Per_Day',
'Sleep_Hours_Per_Night',
'Screen_Time_Hours',
'Social_Media_Hours',
'Productivity_Score'
]
]


plt.figure(figsize=(8,6))

sns.heatmap(
    lifestyle.corr(),
    annot=True
)

plt.title("Lifestyle Features Correlation")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Study_Hours_Per_Day',
    y='Sleep_Hours_Per_Night'
)

plt.title("Study Hours vs Sleep Hours")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Study_Hours_Per_Day',
    y='Previous_Semester_GPA'
)

plt.title("Study Hours vs Previous Semester GPA")
plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Study_Hours_Per_Day',
    y='Assignments_Completed'
)

plt.title("Study Hours vs Assignments Completed")
plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Assignments_Completed',
    y='Productivity_Score'
)

plt.title("Assignments Completed vs Productivity Score")
plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Attendance_Percentage',
    y='Productivity_Score'
)

plt.title("Attendance vs Productivity Score")
plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Class_Participation_Score',
    y='Productivity_Score'
)

plt.title("Class Participation vs Productivity Score")
plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Previous_Semester_GPA',
    y='Productivity_Score'
)

plt.title("GPA vs Productivity Score")
plt.show()

academic = df[
[
'Study_Hours_Per_Day',
'Assignments_Completed',
'Attendance_Percentage',
'Class_Participation_Score',
'Previous_Semester_GPA',
'Productivity_Score'
]
]


plt.figure(figsize=(8,6))

sns.heatmap(
    academic.corr(),
    annot=True
)

plt.title("Academic Features Correlation")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Stress_Level',
    y='Productivity_Score'
)

plt.title("Stress Level vs Productivity Score")
plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Motivation_Level',
    y='Productivity_Score'
)

plt.title("Motivation Level vs Productivity Score")
plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Sleep_Hours_Per_Night',
    y='Stress_Level'
)

plt.title("Sleep Hours vs Stress Level")
plt.show()


plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Study_Hours_Per_Day',
    y='Stress_Level'
)

plt.title("Study Hours vs Stress Level")
plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Attendance_Percentage',
    y='Stress_Level'
)

plt.title("Attendance vs Stress Level")
plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='Assignments_Completed',
    y='Stress_Level'
)

plt.title("Assignments Completed vs Stress Level")
plt.show()

mental = df[
[
'Stress_Level',
'Motivation_Level',
'Sleep_Hours_Per_Night',
'Study_Hours_Per_Day',
'Productivity_Score'
]
]


plt.figure(figsize=(8,6))

sns.heatmap(
    mental.corr(),
    annot=True
)

plt.title("Mental Health Features Correlation")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='AI_Tool_Usage_Hours_Per_Week',
    y='Productivity_Score'
)

plt.title("AI Tool Usage vs Productivity Score")

plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='AI_Tool_Usage_Hours_Per_Week',
    y='Previous_Semester_GPA'
)

plt.title("AI Tool Usage vs GPA")

plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='AI_Tool_Usage_Hours_Per_Week',
    y='Study_Hours_Per_Day'
)

plt.title("AI Tool Usage vs Study Hours")

plt.show()

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='AI_Tool_Usage_Hours_Per_Week',
    y='Stress_Level'
)

plt.title("AI Tool Usage vs Stress Level")

plt.show()

plt.figure(figsize=(8,5))

sns.histplot(
    data=df,
    x='AI_Tool_Usage_Hours_Per_Week',
    kde=True
)

plt.title("AI Usage Distribution")

plt.show()

ai = df[
[
'AI_Tool_Usage_Hours_Per_Week',
'Previous_Semester_GPA',
'Study_Hours_Per_Day',
'Stress_Level',
'Productivity_Score'
]
]


plt.figure(figsize=(8,6))

sns.heatmap(
    ai.corr(),
    annot=True
)

plt.title("AI Usage Correlation")

plt.show()

# %% [markdown]
# FEATURE SELECTION

# %%
corr = df.corr(numeric_only=True)

corr['Productivity_Score'].sort_values(ascending=False)
# Out:
# Productivity_Score                  1.000000
# Sleep_Hours_Per_Night               0.334168
# Motivation_Level                    0.298780
# Assignments_Completed               0.298097
# Attendance_Percentage               0.291535
# Previous_Semester_GPA               0.247190
# Class_Participation_Score           0.243150
# Study_Hours_Per_Day                 0.165509
# Physical_Activity_Hours_Per_Week    0.157227
# Extracurricular_Involvement         0.091514
# Age                                 0.017980
# AI_Tool_Usage_Hours_Per_Week       -0.003690
# Social_Media_Hours                 -0.117147
# Stress_Level                       -0.210958
# Screen_Time_Hours                  -0.221290
# Name: Productivity_Score, dtype: float64

# %%
df.isnull().sum()

df.fillna(
    df.median(numeric_only=True),
    inplace=True
)

plt.figure(figsize=(8,8))

corr['Productivity_Score'].drop(
    'Productivity_Score'
).sort_values().plot(
    kind='barh'
)

plt.title("Feature Correlation with Productivity")

plt.show()
